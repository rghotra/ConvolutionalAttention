# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

import numpy as np
import requests as rq
import os, io, h5py

import models
import utils

tf.config.run_functions_eagerly(True)

# %%
dataset = utils.get_synthetic_dataset()

# %%
model = models.CNN_ATT()

utils.train_model(model, (dataset[0], dataset[1]), (dataset[2], dataset[3]), epochs=75, seed=1)
# Out:
# Epoch 1/75
# 657/657 [==============================] - 67s 102ms/step - loss: 0.8960 - auroc: 0.5012 - aupr: 0.1460 - val_loss: 0.9688 - val_auroc: 0.5028 - val_aupr: 0.1454
# Epoch 2/75
# 657/657 [==============================] - 68s 104ms/step - loss: 0.8733 - auroc: 0.5009 - aupr: 0.1463 - val_loss: 1.1527 - val_auroc: 0.5031 - val_aupr: 0.1453
# Epoch 3/75
# 657/657 [==============================] - 67s 103ms/step - loss: 0.8748 - auroc: 0.4994 - aupr: 0.1461 - val_loss: 1.4103 - val_auroc: 0.5041 - val_aupr: 0.1456
# Epoch 4/75
#  28/657 [>.............................] - ETA: 1:02 - loss: 0.8594 - auroc: 0.5008 - aupr: 0.1408 ETA: 1:03 - loss: 0.8591 - auroc: 0.5009 - aupr:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-29d0be59fb35> in <module>
#       1 model = models.CNN_ATT()
#       2
# ...
