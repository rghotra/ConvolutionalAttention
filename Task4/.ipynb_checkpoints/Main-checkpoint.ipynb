# %%
import pipeline
import models
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
baselines = ['CNN_ATT-pool4_relu', 'CNN_ATT-pool25_relu', 'CNN_ATT-pool4_exp', 'CNN_ATT-pool4_exp']
categories = ['heads', 'key_size']
variants = [[1, 4, 8, 16], [32, 64, 128, 256]]
trials = 5

input_shape = (200, 4)
num_out = 12

b_heads = 8
b_key = 64

# %%
total = 0
for a in range(len(baselines)):
    for i in range(len(categories)):
        for j in range(len(variants[i])):
            for k in range(1, trials+1):
                model_num = a*len(categories)*len(variants[i])*trials + i*len(variants[i])*trials + j*trials + k - 1
                print('\n' + str(model_num/(len(baselines)*len(categories)*len(variants[i])*trials)*100) + '% completed')
                print(baselines[a] + ' ' + categories[i] + ' model-' + str(variants[i][j]) + ' trial-' + str(k))

                num_heads = b_heads if categories[i] != 'heads' else variants[i][j]
                key_size = b_key if categories[i] != 'key_sizes' else variants[i][j]
                pool_size = 4 if a % 2 == 0 else 25
                activation = 'relu' if a < 2 else 'exponential'

                model = models.CNN_ATT(in_shape=input_shape, activation=activation, pool_size=pool_size, heads=num_heads, key_size=key_size, num_out=num_out)
                
                pipeline.execute_pipeline(baselines[a], categories[i], variants[i][j], k, model, 100)
                
                total += 1
# Out:
# 0.0% completed
# CNN_ATT-pool4_relu heads model-1 trial-1
#
# 0.625% completed
# CNN_ATT-pool4_relu heads model-1 trial-2
#
# 1.25% completed
# CNN_ATT-pool4_relu heads model-1 trial-3
#
# 1.875% completed
# CNN_ATT-pool4_relu heads model-1 trial-4
#
# 2.5% completed
# CNN_ATT-pool4_relu heads model-1 trial-5
#
# 3.125% completed
# CNN_ATT-pool4_relu heads model-4 trial-1
#
# 3.75% completed
# CNN_ATT-pool4_relu heads model-4 trial-2
#
# 4.375% completed
# CNN_ATT-pool4_relu heads model-4 trial-3
#
# 5.0% completed
# CNN_ATT-pool4_relu heads model-4 trial-4
#
# 5.625% completed
# CNN_ATT-pool4_relu heads model-4 trial-5
#
# 6.25% completed
# CNN_ATT-pool4_relu heads model-8 trial-1
#
# 6.875000000000001% completed
# CNN_ATT-pool4_relu heads model-8 trial-2
#
# 7.5% completed
# CNN_ATT-pool4_relu heads model-8 trial-3
#
# 8.125% completed
# CNN_ATT-pool4_relu heads model-8 trial-4
#
# 8.75% completed
# CNN_ATT-pool4_relu heads model-8 trial-5
#
# 9.375% completed
# CNN_ATT-pool4_relu heads model-16 trial-1
#
# 10.0% completed
# CNN_ATT-pool4_relu heads model-16 trial-2
#
# 10.625% completed
# CNN_ATT-pool4_relu heads model-16 trial-3
#
# 11.25% completed
# CNN_ATT-pool4_relu heads model-16 trial-4
#
# 11.875% completed
# CNN_ATT-pool4_relu heads model-16 trial-5
#
# 12.5% completed
# CNN_ATT-pool4_relu key_size model-32 trial-1
#
# 13.125% completed
# CNN_ATT-pool4_relu key_size model-32 trial-2
#
# 13.750000000000002% completed
# CNN_ATT-pool4_relu key_size model-32 trial-3
#
# 14.374999999999998% completed
# CNN_ATT-pool4_relu key_size model-32 trial-4
#
# 15.0% completed
# CNN_ATT-pool4_relu key_size model-32 trial-5
#
# 15.625% completed
# CNN_ATT-pool4_relu key_size model-64 trial-1
#
# 16.25% completed
# CNN_ATT-pool4_relu key_size model-64 trial-2
#
# 16.875% completed
# CNN_ATT-pool4_relu key_size model-64 trial-3
#
# 17.5% completed
# CNN_ATT-pool4_relu key_size model-64 trial-4
#
# 18.125% completed
# CNN_ATT-pool4_relu key_size model-64 trial-5
#
# 18.75% completed
# CNN_ATT-pool4_relu key_size model-128 trial-1
#
# 19.375% completed
# CNN_ATT-pool4_relu key_size model-128 trial-2
#
# 20.0% completed
# CNN_ATT-pool4_relu key_size model-128 trial-3
#
# 20.625% completed
# CNN_ATT-pool4_relu key_size model-128 trial-4
#
# 21.25% completed
# CNN_ATT-pool4_relu key_size model-128 trial-5
#
# 21.875% completed
# CNN_ATT-pool4_relu key_size model-256 trial-1
#
# 22.5% completed
# CNN_ATT-pool4_relu key_size model-256 trial-2
#
# 23.125% completed
# CNN_ATT-pool4_relu key_size model-256 trial-3
#
# 23.75% completed
# CNN_ATT-pool4_relu key_size model-256 trial-4
#
# 24.375% completed
# CNN_ATT-pool4_relu key_size model-256 trial-5
#
# 25.0% completed
# CNN_ATT-pool25_relu heads model-1 trial-1
#
# 25.624999999999996% completed
# CNN_ATT-pool25_relu heads model-1 trial-2
#
# 26.25% completed
# CNN_ATT-pool25_relu heads model-1 trial-3
#
# 26.875% completed
# CNN_ATT-pool25_relu heads model-1 trial-4
#
# 27.500000000000004% completed
# CNN_ATT-pool25_relu heads model-1 trial-5
#
# 28.125% completed
# CNN_ATT-pool25_relu heads model-4 trial-1
#
# 28.749999999999996% completed
# CNN_ATT-pool25_relu heads model-4 trial-2
#
# 29.375% completed
# CNN_ATT-pool25_relu heads model-4 trial-3
#
# 30.0% completed
# CNN_ATT-pool25_relu heads model-4 trial-4
#
# 30.625000000000004% completed
# CNN_ATT-pool25_relu heads model-4 trial-5
#
# 31.25% completed
# CNN_ATT-pool25_relu heads model-8 trial-1
#
# 31.874999999999996% completed
# CNN_ATT-pool25_relu heads model-8 trial-2
#
# 32.5% completed
# CNN_ATT-pool25_relu heads model-8 trial-3
#
# 33.125% completed
# CNN_ATT-pool25_relu heads model-8 trial-4
#
# 33.75% completed
# CNN_ATT-pool25_relu heads model-8 trial-5
#
# 34.375% completed
# CNN_ATT-pool25_relu heads model-16 trial-1
#
# 35.0% completed
# CNN_ATT-pool25_relu heads model-16 trial-2
#
# 35.625% completed
# CNN_ATT-pool25_relu heads model-16 trial-3
#
# 36.25% completed
# CNN_ATT-pool25_relu heads model-16 trial-4
#
# 36.875% completed
# CNN_ATT-pool25_relu heads model-16 trial-5
#
# 37.5% completed
# CNN_ATT-pool25_relu key_size model-32 trial-1
#
# 38.125% completed
# CNN_ATT-pool25_relu key_size model-32 trial-2
#
# 38.75% completed
# CNN_ATT-pool25_relu key_size model-32 trial-3
#
# 39.375% completed
# CNN_ATT-pool25_relu key_size model-32 trial-4
#
# 40.0% completed
# CNN_ATT-pool25_relu key_size model-32 trial-5
#
# 40.625% completed
# CNN_ATT-pool25_relu key_size model-64 trial-1
#
# 41.25% completed
# CNN_ATT-pool25_relu key_size model-64 trial-2
#
# 41.875% completed
# CNN_ATT-pool25_relu key_size model-64 trial-3
#
# 42.5% completed
# CNN_ATT-pool25_relu key_size model-64 trial-4
#
# 43.125% completed
# CNN_ATT-pool25_relu key_size model-64 trial-5
#
# 43.75% completed
# CNN_ATT-pool25_relu key_size model-128 trial-1
#
# 44.375% completed
# CNN_ATT-pool25_relu key_size model-128 trial-2
#
# 45.0% completed
# CNN_ATT-pool25_relu key_size model-128 trial-3
#
# 45.625% completed
# CNN_ATT-pool25_relu key_size model-128 trial-4
#
# 46.25% completed
# CNN_ATT-pool25_relu key_size model-128 trial-5
#
# 46.875% completed
# CNN_ATT-pool25_relu key_size model-256 trial-1
#
# 47.5% completed
# CNN_ATT-pool25_relu key_size model-256 trial-2
#
# 48.125% completed
# CNN_ATT-pool25_relu key_size model-256 trial-3
#
# 48.75% completed
# CNN_ATT-pool25_relu key_size model-256 trial-4
#
# 49.375% completed
# CNN_ATT-pool25_relu key_size model-256 trial-5
#
# 50.0% completed
# CNN_ATT-pool4_exp heads model-1 trial-1
#
# 50.625% completed
# CNN_ATT-pool4_exp heads model-1 trial-2
#
# 51.24999999999999% completed
# CNN_ATT-pool4_exp heads model-1 trial-3
#
# 51.87500000000001% completed
# CNN_ATT-pool4_exp heads model-1 trial-4
#
# 52.5% completed
# CNN_ATT-pool4_exp heads model-1 trial-5
#
# 53.125% completed
# CNN_ATT-pool4_exp heads model-4 trial-1
#
# 53.75% completed
# CNN_ATT-pool4_exp heads model-4 trial-2
#
# 54.37499999999999% completed
# CNN_ATT-pool4_exp heads model-4 trial-3
#
# 55.00000000000001% completed
# CNN_ATT-pool4_exp heads model-4 trial-4
#
# 55.625% completed
# CNN_ATT-pool4_exp heads model-4 trial-5
#
# 56.25% completed
# CNN_ATT-pool4_exp heads model-8 trial-1
#
# 56.875% completed
# CNN_ATT-pool4_exp heads model-8 trial-2
#
# 57.49999999999999% completed
# CNN_ATT-pool4_exp heads model-8 trial-3
#
# 58.12500000000001% completed
# CNN_ATT-pool4_exp heads model-8 trial-4
#
# 58.75% completed
# CNN_ATT-pool4_exp heads model-8 trial-5
#
# 59.375% completed
# CNN_ATT-pool4_exp heads model-16 trial-1
#
# 60.0% completed
# CNN_ATT-pool4_exp heads model-16 trial-2
#
# 60.62499999999999% completed
# CNN_ATT-pool4_exp heads model-16 trial-3
#
# 61.25000000000001% completed
# CNN_ATT-pool4_exp heads model-16 trial-4
#
# 61.875% completed
# CNN_ATT-pool4_exp heads model-16 trial-5
#
# 62.5% completed
# CNN_ATT-pool4_exp key_size model-32 trial-1
#
# 63.125% completed
# CNN_ATT-pool4_exp key_size model-32 trial-2
#
# 63.74999999999999% completed
# CNN_ATT-pool4_exp key_size model-32 trial-3
#
# 64.375% completed
# CNN_ATT-pool4_exp key_size model-32 trial-4
#
# 65.0% completed
# CNN_ATT-pool4_exp key_size model-32 trial-5
#
# 65.625% completed
# CNN_ATT-pool4_exp key_size model-64 trial-1
#
# 66.25% completed
# CNN_ATT-pool4_exp key_size model-64 trial-2
#
# 66.875% completed
# CNN_ATT-pool4_exp key_size model-64 trial-3
#
# 67.5% completed
# CNN_ATT-pool4_exp key_size model-64 trial-4
#
# 68.125% completed
# CNN_ATT-pool4_exp key_size model-64 trial-5
#
# 68.75% completed
# CNN_ATT-pool4_exp key_size model-128 trial-1
#
# 69.375% completed
# CNN_ATT-pool4_exp key_size model-128 trial-2
#
# 70.0% completed
# CNN_ATT-pool4_exp key_size model-128 trial-3
#
# 70.625% completed
# CNN_ATT-pool4_exp key_size model-128 trial-4
#
# 71.25% completed
# CNN_ATT-pool4_exp key_size model-128 trial-5
#
# 71.875% completed
# CNN_ATT-pool4_exp key_size model-256 trial-1
#
# 72.5% completed
# CNN_ATT-pool4_exp key_size model-256 trial-2
#
# 73.125% completed
# CNN_ATT-pool4_exp key_size model-256 trial-3
#
# 73.75% completed
# CNN_ATT-pool4_exp key_size model-256 trial-4
#
# 74.375% completed
# CNN_ATT-pool4_exp key_size model-256 trial-5
#
# 75.0% completed
# CNN_ATT-pool4_exp heads model-1 trial-1
#
# 75.625% completed
# CNN_ATT-pool4_exp heads model-1 trial-2
#
# 76.25% completed
# CNN_ATT-pool4_exp heads model-1 trial-3
#
# 76.875% completed
# CNN_ATT-pool4_exp heads model-1 trial-4
#
# 77.5% completed
# CNN_ATT-pool4_exp heads model-1 trial-5
#
# 78.125% completed
# CNN_ATT-pool4_exp heads model-4 trial-1
#
# 78.75% completed
# CNN_ATT-pool4_exp heads model-4 trial-2
#
# 79.375% completed
# CNN_ATT-pool4_exp heads model-4 trial-3
#
# 80.0% completed
# CNN_ATT-pool4_exp heads model-4 trial-4
#
# 80.625% completed
# CNN_ATT-pool4_exp heads model-4 trial-5
#
# 81.25% completed
# CNN_ATT-pool4_exp heads model-8 trial-1
#
# 81.875% completed
# CNN_ATT-pool4_exp heads model-8 trial-2
#
# 82.5% completed
# CNN_ATT-pool4_exp heads model-8 trial-3
#
# 83.125% completed
# CNN_ATT-pool4_exp heads model-8 trial-4
#
# 83.75% completed
# CNN_ATT-pool4_exp heads model-8 trial-5
#
# 84.375% completed
# CNN_ATT-pool4_exp heads model-16 trial-1
#
# 85.0% completed
# CNN_ATT-pool4_exp heads model-16 trial-2
#
# 85.625% completed
# CNN_ATT-pool4_exp heads model-16 trial-3
#
# 86.25% completed
# CNN_ATT-pool4_exp heads model-16 trial-4
#
# 86.875% completed
# CNN_ATT-pool4_exp heads model-16 trial-5
#
# 87.5% completed
# CNN_ATT-pool4_exp key_size model-32 trial-1
#
# 88.125% completed
# CNN_ATT-pool4_exp key_size model-32 trial-2
#
# 88.75% completed
# CNN_ATT-pool4_exp key_size model-32 trial-3
#
# 89.375% completed
# CNN_ATT-pool4_exp key_size model-32 trial-4
#
# 90.0% completed
# CNN_ATT-pool4_exp key_size model-32 trial-5
#
# 90.625% completed
# CNN_ATT-pool4_exp key_size model-64 trial-1
#
# 91.25% completed
# CNN_ATT-pool4_exp key_size model-64 trial-2
#
# 91.875% completed
# CNN_ATT-pool4_exp key_size model-64 trial-3
#
# 92.5% completed
# CNN_ATT-pool4_exp key_size model-64 trial-4
#
# 93.125% completed
# CNN_ATT-pool4_exp key_size model-64 trial-5
#
# 93.75% completed
# CNN_ATT-pool4_exp key_size model-128 trial-1
#
# 94.375% completed
# CNN_ATT-pool4_exp key_size model-128 trial-2
#
# 95.0% completed
# CNN_ATT-pool4_exp key_size model-128 trial-3
#
# 95.625% completed
# CNN_ATT-pool4_exp key_size model-128 trial-4
#
# 96.25% completed
# CNN_ATT-pool4_exp key_size model-128 trial-5
#
# 96.875% completed
# CNN_ATT-pool4_exp key_size model-256 trial-1
#
# 97.5% completed
# CNN_ATT-pool4_exp key_size model-256 trial-2
#
# 98.125% completed
# CNN_ATT-pool4_exp key_size model-256 trial-3
#
# 98.75% completed
# CNN_ATT-pool4_exp key_size model-256 trial-4
#
# 99.375% completed
# CNN_ATT-pool4_exp key_size model-256 trial-5
